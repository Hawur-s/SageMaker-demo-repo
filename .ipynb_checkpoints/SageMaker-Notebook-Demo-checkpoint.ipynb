# %%
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen
import pandas as pd
import numpy as np
from datetime import date, datetime
import matplotlib.pyplot as plt
import gc #garbage collector
import plotly.graph_objects as go
import plotly.offline as py
py.init_notebook_mode(connected=True)
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fname = 'https://www.worldometers.info/coronavirus/#countries'
req = Request(fname, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req)
page_soup = soup(webpage, "html.parser")
today = datetime.now()
today_str = "%s %d, %d" % (date.today().strftime("%b"), today.day, today.year)
yesterday_str = "%s %d, %d" % (date.today().strftime("%b"), today.day-1, today.year)
clean = True

# %%
print("This version of the notebook is being run on %s." % today_str)
# Out:
# This version of the notebook is being run on Mar 10, 2021.

# %%
table = page_soup.findAll("table", {"id": "main_table_countries_yesterday"})
containers = table[0].findAll("tr", {"style": ""})
del containers[0]

all_data = []
for country in containers:
    country_data = []
    country_container = country.findAll("td")
    if country_container[1].text == 'China':
        continue
    for i in range(1, len(country_container)):
        final_feature = country_container[i].text
        if clean:
            if i != 1 and i != len(country_container)-1:
                final_feature = final_feature.replace(',', '')
                if final_feature.find('+') != -1:
                    final_feature = final_feature.replace('+', '')
                    final_feature = float(final_feature)
                elif final_feature.find('-') != -1:
                    final_feature = final_feature.replace('-', '')
                    final_feature = float(final_feature)*-1
        if final_feature == 'N/A':
            final_feature = 0
        elif final_feature == '' or final_feature == ' ':
            final_feature = -1 #None
        country_data.append(final_feature)
    all_data.append(country_data)

# %%
df = pd.DataFrame(all_data)
df = df.drop([15, 16, 17], axis=1) # Get rid of unnecessary data

# %%
column_labels = ["Country", "Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical",
                "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population", "Continent"]
df.columns = column_labels

# %%
country_labels = page_soup.findAll("a", {"class": "mt_a"})
c_label = []
for country in country_labels:
    c_label.append(country.text)
c_label = set(c_label)

not_counted = []
sorted_countries = set(df['Country']) #Increase computational speed
for country in c_label:
    if country not in sorted_countries:
        not_counted.append(country)

# %%
print(not_counted + ['China'])
# Out:
# ['Micronesia', 'Saint Pierre Miquelon', 'Saint Kitts and Nevis', 'Marshall Islands', 'Anguilla', 'Tajikistan', 'Grenada', 'Greenland', 'China', 'China']

# %%
for label in df.columns:
    if label != 'Country' and label != 'Continent':
        df[label] = pd.to_numeric(df[label])

# %%
df['%Inc Cases'] = df['New Cases']/df['Total Cases']*100
df['%Inc Deaths'] = df['New Deaths']/df['Total Deaths']*100
df['%Inc Recovered'] = df['New Recovered']/df['Total Recovered']*100

# %%
pd.options.display.max_rows = None
df
# Out:
#                     Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0                     World    118146858   388763.0       2621297      9069.0
# 1                       USA     29801506    55683.0        540574      1704.0
# 2                     India     11261470    16846.0        158079       113.0
# 3                    Brazil     11125017    69537.0        268568      1954.0
# 4                    Russia      4342474     9445.0         89809       336.0
# 5                        UK      4228998     5766.0        124797       231.0
# 6                    France      3932862    23302.0         89301       316.0
# 7                     Spain      3164983     4013.0         71727       291.0
# 8                     Italy      3101093    19749.0        100479       376.0
# 9                    Turkey      2807387    13755.0         29160        66.0
# 10                  Germany      2520609     6841.0         72981       283.0
# 11                 Colombia      2282372     3511.0         60676        78.0
# 12                Argentina      2162001     7307.0         53252       131.0
# 13                   Mexico      2130477     1877.0        190923       319.0
# 14                   Poland      1811036     9954.0         45599       282.0
# 15                     Iran      1706559     8554.0         60867        81.0
# 16             South Africa      1522697      991.0         50906       103.0
# 17                  Ukraine      1410061     3261.0         27204        76.0
# 18                Indonesia      1392945     6389.0         37757       210.0
# 19                     Peru      1380023     5556.0         48163       190.0
# 20                  Czechia      1335999    10594.0         22280       207.0
# 21              Netherlands      1128202     4293.0         15917        56.0
# 22                   Canada       893518     2820.0         22304        28.0
# 23                    Chile       864064     3531.0         21182        19.0
# 24                  Romania       835552     4989.0         21056        93.0
# 25                 Portugal       811306      847.0         16595        30.0
# 26                   Israel       808262     3671.0          5933        18.0
# 27                  Belgium       789008     1117.0         22292        31.0
# 28                     Iraq       735626     4610.0         13618        22.0
# 29                   Sweden       695975       -1.0         13042        34.0
# 30              Philippines       600428     2668.0         12528         7.0
# 31                 Pakistan       593453     1353.0         13281        54.0
# 32              Switzerland       566412     1378.0         10065         9.0
# 33               Bangladesh       552087      912.0          8489        13.0
# 34                   Serbia       494106     4576.0          4599        20.0
# 35                  Morocco       486833      508.0          8695        12.0
# 36                  Austria       479391     2411.0          8757        25.0
# 37                  Hungary       475207     6494.0         16146       158.0
# 38                   Jordan       442202     7072.0          5046        59.0
# 39                    Japan       440671      679.0          8299        46.0
# 40                      UAE       415705     2373.0          1345        10.0
# 41                  Lebanon       401826     3939.0          5134        45.0
# 42             Saudi Arabia       380572      390.0          6539         5.0
# 43                   Panama       345759      523.0          5944        10.0
# 44                 Slovakia       325993     2207.0          8037       116.0
# 45                 Malaysia       316269     1280.0          1186         9.0
# 46                  Belarus       297514     1073.0          2055         8.0
# 47                  Ecuador       295114      496.0         16069        26.0
# 48                    Nepal       274869       59.0          3012         1.0
# 49                  Georgia       273137      139.0          3601        10.0
# 50                 Bulgaria       266805     3502.0         10902       138.0
# 51                  Bolivia       254736      463.0         11845        22.0
# 52                  Croatia       247099      491.0          5621        19.0
# 53       Dominican Republic       243778      252.0          3191        12.0
# 54                  Tunisia       238613      596.0          8268        43.0
# 55               Azerbaijan       237260      297.0          3250         3.0
# 56                  Ireland       223957      306.0          4452        30.0
# 57               Kazakhstan       219325      571.0          2819        -1.0
# 58                  Denmark       215791      527.0          2381        -1.0
# 59                   Greece       209462     3181.0          6843        46.0
# 60               Costa Rica       207832      372.0          2848         7.0
# 61                   Kuwait       203055     1157.0          1141         8.0
# 62                Lithuania       202926      488.0          3343         6.0
# 63                Palestine       200382     1828.0          2170        13.0
# 64                  Moldova       196475      873.0          4150        21.0
# 65                 Slovenia       196421      740.0          3904         7.0
# 66                    Egypt       187716      622.0         11082        44.0
# 67                Guatemala       179563      793.0          6493        14.0
# 68                  Armenia       175198      182.0          3232         7.0
# 69                 Honduras       174243      514.0          4283        23.0
# 70                 Paraguay       171985     2125.0          3360        17.0
# 71                 Ethiopia       168335     1202.0          2451         9.0
# 72                    Qatar       167888      471.0           264         1.0
# 73                  Nigeria       159252      346.0          1988         6.0
# 74                     Oman       144831      427.0          1597         3.0
# 75                Venezuela       143321      547.0          1399         8.0
# 76                  Myanmar       142059       14.0          3200        -1.0
# 77                    Libya       140688     1030.0          2297         9.0
# 78   Bosnia and Herzegovina       138542     1251.0          5345        48.0
# 79                  Bahrain       127800      545.0           474         1.0
# 80                  Algeria       114543      161.0          3022         4.0
# 81                  Albania       114209      629.0          1969        13.0
# 82                    Kenya       109643      479.0          1886         7.0
# 83          North Macedonia       108350      871.0          3228        22.0
# 84                 S. Korea        93263      446.0          1645         3.0
# 85                   Latvia        90997      472.0          1705         6.0
# 86                    Ghana        86737      272.0           656         9.0
# 87               Kyrgyzstan        86606       23.0          1475         2.0
# 88                Sri Lanka        86343      304.0           511         4.0
# 89                   Zambia        82897      242.0          1137         5.0
# 90               Montenegro        80803      612.0          1092         7.0
# 91               Uzbekistan        80247       28.0           622        -1.0
# 92                  Estonia        77489     1306.0           669         2.0
# 93                   Norway        76484      714.0           632        -1.0
# 94                  Uruguay        65527      827.0           666         8.0
# 95                  Finland        63110      588.0           776         2.0
# 96               Mozambique        62882      179.0           700         2.0
# 97              El Salvador        61539      141.0          1923         8.0
# 98                Singapore        60052        6.0            29        -1.0
# 99                     Cuba        57607     1041.0           352         2.0
# 100              Luxembourg        56822      145.0           668         5.0
# 101             Afghanistan        55894       26.0          2451        -1.0
# 102                  Uganda        40490       11.0           334        -1.0
# 103                 Namibia        40337      150.0           444         5.0
# 104                  Cyprus        37650      420.0           233        -1.0
# 105                Cameroon        36794       -1.0           566        -1.0
# 106                Zimbabwe        36321       32.0          1489         2.0
# 107                 Senegal        36039       80.0           930         5.0
# 108             Ivory Coast        35477      146.0           206         2.0
# 109                Botswana        32912       -1.0           413        -1.0
# 110                  Malawi        32528       59.0          1074         4.0
# 111               Australia        29061       15.0           909        -1.0
# 112                   Sudan        28766       -1.0          1915        -1.0
# 113                 Jamaica        27465      561.0           460         6.0
# 114                     DRC        26684       57.0           712        -1.0
# 115                Thailand        26501       60.0            85        -1.0
# 116                   Malta        24847      248.0           335         1.0
# 117                  Angola        21114        6.0           516         1.0
# 118                Maldives        21034      115.0            64        -1.0
# 119              Madagascar        20155       -1.0           300        -1.0
# 120                  Rwanda        19779      120.0           270         2.0
# 121        French Polynesia        18495       13.0           141        -1.0
# 122                 Mayotte        18413       98.0           129         1.0
# 123              Mauritania        17365       25.0           442        -1.0
# 124                Eswatini        17191        3.0           658        -1.0
# 125                  Guinea        16912       -1.0            97        -1.0
# 126           French Guiana        16693       -1.0            87        -1.0
# 127                   Syria        16117       75.0          1074         6.0
# 128                   Gabon        16015       -1.0            91        -1.0
# 129              Cabo Verde        15826       20.0           154        -1.0
# 130                 Réunion        13801      676.0            71        12.0
# 131                   Haiti        12594       58.0           250        -1.0
# 132                  Belize        12345       10.0           316         1.0
# 133            Burkina Faso        12187        6.0           143        -1.0
# 134               Hong Kong        11121       21.0           202        -1.0
# 135                 Andorra        11089       20.0           112        -1.0
# 136                 Lesotho        10525        2.0           309         1.0
# 137              Guadeloupe        10149       -1.0           162        -1.0
# 138                   Congo         9179       -1.0           131        -1.0
# 139                Suriname         8985        5.0           175        -1.0
# 140             South Sudan         8870       -1.0           102        -1.0
# 141                  Guyana         8847       33.0           204         1.0
# 142                 Bahamas         8642        1.0           185         2.0
# 143                    Mali         8613       -1.0           358        -1.0
# 144                 Somalia         8577      139.0           319        12.0
# 145                   Aruba         8177       67.0            77        -1.0
# 146     Trinidad and Tobago         7736       -1.0           140        -1.0
# 147                    Togo         7680       82.0            92        -1.0
# 148              Martinique         6928      110.0            47         1.0
# 149               Nicaragua         6537       48.0           175         1.0
# 150       Equatorial Guinea         6371       -1.0            96        -1.0
# 151                   Benin         6338       -1.0            81        -1.0
# 152                Djibouti         6181       24.0            63        -1.0
# 153                 Iceland         6067        3.0            29        -1.0
# 154                     CAR         5023        2.0            63        -1.0
# 155                   Niger         4835        7.0           177        -1.0
# 156                 Curaçao         4830       17.0            22        -1.0
# 157                  Gambia         4792       -1.0           153        -1.0
# 158               Gibraltar         4255        6.0            93        -1.0
# 159                    Chad         4214       21.0           148         2.0
# 160         Channel Islands         4043        1.0            86        -1.0
# 161              San Marino         3984       46.0            77         1.0
# 162            Sierra Leone         3922        1.0            79        -1.0
# 163             Saint Lucia         3902       31.0            46        -1.0
# 164                 Comoros         3606       -1.0           146        -1.0
# 165                Mongolia         3372       36.0             3        -1.0
# 166                Barbados         3333       30.0            37        -1.0
# 167           Guinea-Bissau         3319        7.0            49        -1.0
# 168              Seychelles         3032       32.0            15        -1.0
# 169                 Eritrea         2944       -1.0             7        -1.0
# 170           Liechtenstein         2594        2.0            55         1.0
# 171                   Yemen         2586       41.0           654         1.0
# 172                 Vietnam         2526        2.0            35        -1.0
# 173             New Zealand         2409        4.0            26        -1.0
# 174                 Burundi         2339        5.0             3        -1.0
# 175        Turks and Caicos         2177       -1.0            15        -1.0
# 176            Sint Maarten         2076        2.0            27        -1.0
# 177                  Monaco         2048       20.0            26        -1.0
# 178                 Liberia         2026        2.0            85        -1.0
# 179   Sao Tome and Principe         1977       16.0            32        -1.0
# 180        Papua New Guinea         1670       -1.0            16        -1.0
# 181  St. Vincent Grenadines         1663       -1.0             8        -1.0
# 182            Saint Martin         1571       -1.0            12        -1.0
# 183                Cambodia         1060       49.0            -1        -1.0
# 184                  Taiwan          977        1.0            10        -1.0
# 185             Isle of Man          952       87.0            25        -1.0
# 186                  Bhutan          868       -1.0             1        -1.0
# 187     Antigua and Barbuda          862       14.0            22         1.0
# 188                 Bermuda          724       -1.0            12        -1.0
# 189          Faeroe Islands          660       -1.0             1        -1.0
# 190               Mauritius          641       -1.0            10        -1.0
# 191               St. Barth          638       -1.0             1        -1.0
# 192   Caribbean Netherlands          587       47.0             5        -1.0
# 193                Tanzania          509       -1.0            21        -1.0
# 194          Cayman Islands          460        9.0             2        -1.0
# 195                 Brunei           191        1.0             3        -1.0
# 196  British Virgin Islands          153       -1.0             1        -1.0
# 197                Dominica          151        7.0            -1        -1.0
# 198             Timor-Leste          142       20.0            -1        -1.0
# 199           New Caledonia           70        3.0            -1        -1.0
# 200                    Fiji           66       -1.0             2        -1.0
# 201        Falkland Islands           54       -1.0            -1        -1.0
# 202                   Macao           48       -1.0            -1        -1.0
# 203                    Laos           47       -1.0            -1        -1.0
# 204            Vatican City           27       -1.0            -1        -1.0
# 205              Montserrat           20       -1.0             1        -1.0
# 206       Wallis and Futuna           19        3.0            -1        -1.0
# 207         Solomon Islands           18       -1.0            -1        -1.0
# 208          Western Sahara           10       -1.0             1        -1.0
# 209                   Samoa            3       -1.0            -1        -1.0
# 210                 Vanuatu            3       -1.0            -1        -1.0
# 211                  Total:    118146858   388763.0       2621297      9069.0
#
#      Total Recovered  New Recovered  Active Cases  Serious/Critical  \
# 0           93848824       401854.0    21676737.0             89723
# 1           20549678        99762.0     8711254.0             12715
# 2           10917624        20138.0      185767.0              8944
# 3            9843218        60898.0     1013231.0              8318
# 4            3932177         9931.0      320488.0              2300
# 5            3315934        37305.0      788267.0              1356
# 6             267539         1443.0     3576022.0              3918
# 7            2823433        12504.0      269823.0              2358
# 8            2521731        12999.0      478883.0              2756
# 9            2640669         8639.0      137558.0              1289
# 10           2319600         8700.0      128028.0              2848
# 11           2183635         2858.0       38061.0              1982
# 12           1956591         5051.0      152158.0              3525
# 13           1675996         5565.0      263558.0              4798
# 14           1503353         9270.0      262084.0              1837
# 15           1456759         7409.0      188933.0              3811
# 16           1444282         2237.0       27509.0               546
# 17           1199229          975.0      183628.0               177
# 18           1210877         7496.0      144311.0                -1
# 19           1288067         5839.0       43793.0              2192
# 20           1164688          392.0      149031.0              1789
# 21                 0            0.0           0.0               556
# 22            841035         2945.0       30179.0               549
# 23            814088         4147.0       28794.0              1839
# 24            767219         5588.0       47277.0              1126
# 25            734218         1872.0       60493.0               312
# 26            764445         3087.0       37884.0               664
# 27             53588           71.0      713128.0               425
# 28            668153         3692.0       53855.0               428
# 29                 0            0.0           0.0               216
# 30            546078          171.0       41822.0               785
# 31            563823         3365.0       16349.0              1644
# 32            521912           -1.0       34435.0               167
# 33            505349         1229.0       38249.0                -1
# 34            400347           -1.0       89160.0               189
# 35            473208          664.0        4930.0               272
# 36            447041         2009.0       23593.0               338
# 37            338946         2202.0      120115.0               833
# 38            375478         4024.0       61678.0               506
# 39            420260         1031.0       12112.0               381
# 40            396433         1784.0       17927.0                -1
# 41            314783         2036.0       81909.0               932
# 42            371338          306.0        2695.0               515
# 43            333005          786.0        6810.0               195
# 44            255300           -1.0       62656.0               740
# 45            296379         2345.0       18704.0               155
# 46            288049          852.0        7410.0                -1
# 47            256009           -1.0       23036.0               529
# 48            270987           60.0         870.0                -1
# 49            267015          129.0        2521.0                -1
# 50            217518         3403.0       38385.0               497
# 51            199000          764.0       43891.0                71
# 52            238121          464.0        3357.0                78
# 53            198947          561.0       41640.0               185
# 54            205176         2182.0       25169.0               273
# 55            229915          126.0        4095.0                -1
# 56             23364           -1.0      196141.0                93
# 57            202694          464.0       13812.0               221
# 58            206421          589.0        6989.0                38
# 59            179672         3594.0       22947.0               477
# 60            188151          176.0       16833.0               139
# 61            188167         1045.0       13747.0               181
# 62            189070          825.0       10513.0               148
# 63            178121         1614.0       20091.0               155
# 64            173141          899.0       19184.0               331
# 65            181915          892.0       10602.0                90
# 66            144917          432.0       31717.0                90
# 67            165897          582.0        7173.0                 5
# 68            165096          142.0        6870.0                -1
# 69             68085           96.0      101875.0               416
# 70            142893         1211.0       25732.0               324
# 71            139532          893.0       26352.0               427
# 72            156612          313.0       11012.0               116
# 73            139056          554.0       18208.0                10
# 74            135005          321.0        8229.0                75
# 75            135389          550.0        6533.0               139
# 76            131702           23.0        7157.0                -1
# 77            128002         1124.0       10389.0                -1
# 78            119135          415.0       14062.0                -1
# 79            121106          617.0        6220.0                56
# 80             79319          132.0       32202.0                19
# 81             76784          897.0       35456.0                46
# 82             87736          113.0       20021.0                86
# 83             95822          412.0        9300.0               124
# 84             83900          426.0        7718.0               128
# 85             80892          645.0        8400.0                84
# 86             81299          347.0        4782.0                90
# 87             83606           31.0        1525.0                16
# 88             82753          240.0        3079.0                -1
# 89             79162          441.0        2598.0               181
# 90             70648          511.0        9063.0                69
# 91             78939           24.0         686.0                27
# 92             57206         1565.0       19614.0                53
# 93             66014           -1.0        9838.0                19
# 94             56399          761.0        8462.0                88
# 95             46000           -1.0       16334.0                40
# 96             47729         1135.0       14453.0                -1
# 97             57958          225.0        1658.0                53
# 98             59905            5.0         118.0                 1
# 99             52593          884.0        4662.0                69
# 100            53266           26.0        2888.0                21
# 101            49409            7.0        4034.0              1084
# 102            15075           10.0       25081.0                -1
# 103            37893          315.0        2000.0                28
# 104             2057           -1.0       35360.0                29
# 105            32936           -1.0        3292.0                53
# 106            33919           47.0         913.0                25
# 107            31184          269.0        3925.0                38
# 108            32882           82.0        2389.0                -1
# 109            27765           -1.0        4734.0                 1
# 110            23691          586.0        7763.0                69
# 111            26204            9.0        1948.0                -1
# 112            23268           -1.0        3583.0                -1
# 113            14595          148.0       12410.0                29
# 114            22432           -1.0        3540.0                -1
# 115            25851           74.0         565.0                 1
# 116            21477          390.0        3035.0                18
# 117            19677           20.0         921.0                10
# 118            18428          175.0        2542.0               179
# 119            19543           -1.0         312.0                23
# 120            18033          122.0        1476.0                20
# 121             4842           -1.0       13512.0                 2
# 122             2964           -1.0       15320.0                24
# 123            16715           27.0         208.0                14
# 124            15448          105.0        1085.0                36
# 125            15236           -1.0        1579.0                24
# 126             9995           -1.0        6611.0                 6
# 127            10541           87.0        4502.0                -1
# 128            14047           -1.0        1877.0                23
# 129            15159           26.0         513.0                23
# 130            12389          433.0        1341.0                58
# 131             9967          139.0        2377.0                -1
# 132            11957           31.0          72.0                 2
# 133            11860           44.0         184.0                -1
# 134            10661           25.0         258.0                14
# 135            10685           24.0         292.0                17
# 136             3922           -1.0        6294.0                -1
# 137             2242           -1.0        7745.0                 5
# 138             7514           -1.0        1534.0                -1
# 139             8487           14.0         323.0                 2
# 140             4914           -1.0        3854.0                 8
# 141             8200           29.0         443.0                 7
# 142             7483           18.0         974.0                 1
# 143             6450           -1.0        1805.0                -1
# 144             4031           99.0        4227.0                -1
# 145             7893           65.0         207.0                11
# 146             7503           -1.0          93.0                 2
# 147             6460          120.0        1128.0                -1
# 148               98           -1.0        6783.0                 3
# 149             4225           -1.0        2137.0                -1
# 150             5739           -1.0         536.0                24
# 151             5383           -1.0         874.0                35
# 152             5940            5.0         178.0                -1
# 153             6022            2.0          16.0                 6
# 154             4920           -1.0          40.0                 2
# 155             4415            8.0         243.0                23
# 156             4682            5.0         126.0                 5
# 157             4203           -1.0         436.0                 8
# 158             4136            2.0          26.0                 1
# 159             3724           34.0         342.0                -1
# 160             3958           10.0          -1.0                 1
# 161             3457           21.0         450.0                 9
# 162             2741           20.0        1102.0                -1
# 163             3595           29.0         261.0                 2
# 164             3427           -1.0          33.0                -1
# 165             2765          177.0         604.0                 7
# 166             2915           68.0         381.0                -1
# 167             2686           15.0         584.0                 7
# 168             2809           66.0         208.0                -1
# 169             2436           -1.0         501.0                -1
# 170             2519           -1.0          20.0                 1
# 171             1451            4.0         481.0                23
# 172             2004           84.0         487.0                -1
# 173             2304            3.0          79.0                -1
# 174              773           -1.0        1563.0                -1
# 175             2020           -1.0         142.0                 5
# 176             2031            3.0          18.0                 1
# 177             1869           19.0         153.0                 4
# 178             1898            6.0          43.0                 2
# 179             1649           65.0         296.0                -1
# 180              846           -1.0         808.0                -1
# 181             1100           73.0         555.0                 2
# 182             1399           -1.0         160.0                 7
# 183              538           21.0         522.0                -1
# 184              932           -1.0          35.0                -1
# 185              417           -1.0         510.0                 2
# 186              866           -1.0           1.0                -1
# 187              455           45.0         385.0                45
# 188              690           -1.0          22.0                -1
# 189              657           -1.0           2.0                -1
# 190              588           -1.0          43.0                -1
# 191              462           -1.0         175.0                -1
# 192              453           10.0         129.0                -1
# 193              183           -1.0         305.0                 7
# 194              426           -1.0          32.0                -1
# 195              183            1.0           5.0                -1
# 196              131           -1.0          21.0                -1
# 197              138            8.0          13.0                -1
# 198               94           -1.0          48.0                -1
# 199               58           -1.0          12.0                -1
# 200               57           -1.0           7.0                -1
# 201               51           -1.0           3.0                -1
# 202               47           -1.0           1.0                -1
# 203               42           -1.0           5.0                -1
# 204               15           -1.0          12.0                -1
# 205               14           -1.0           5.0                -1
# 206                7           -1.0          12.0                 1
# 207               14           -1.0           4.0                -1
# 208                8           -1.0           1.0                -1
# 209                2           -1.0           1.0                -1
# 210                1           -1.0           2.0                -1
# 211         93848824       401854.0    21676737.0             89723
#
#      Tot Cases/1M  Deaths/1M  Total Tests  Tests/1M  Population  \
# 0         15157.0      336.3           -1        -1          -1
# 1         89673.0     1627.0    371894718   1119032   332336197
# 2          8106.0      114.0    222716796    160308  1389308662
# 3         52084.0     1257.0     28600000    133897   213596922
# 4         29748.0      615.0    113700000    778887   145977558
# 5         62071.0     1832.0     98133566   1440364    68131084
# 6         60160.0     1366.0     55599261    850494    65372907
# 7         67675.0     1534.0     40292390    861551    46767250
# 8         51342.0     1664.0     42872865    709809    60400547
# 9         33043.0      343.0     34403108    404928    84961145
# 10        30019.0      869.0     45114160    537277    83968223
# 11        44530.0     1184.0     11784331    229917    51254665
# 12        47537.0     1171.0      7791570    171318    45480270
# 13        16406.0     1470.0      5626739     43329   129861409
# 14        47888.0     1206.0     10328276    273104    37818045
# 15        20141.0      718.0     11274630    133067    84729135
# 16        25454.0      851.0      9299884    155462    59820794
# 17        32376.0      625.0      7062386    162159    43552328
# 18         5056.0      137.0     11266592     40894   275506383
# 19        41459.0     1447.0      7986252    239927    33286198
# 20       124596.0     2078.0      8877876    827955    10722655
# 21        65742.0      928.0      6970400    406178    17160963
# 22        23533.0      587.0     25352166    667703    37969201
# 23        44936.0     1102.0      9819159    510649    19228797
# 24        43634.0     1100.0      6574329    343324    19149049
# 25        79726.0     1631.0      8429713    828375    10176204
# 26        87878.0      645.0     12581283   1367889     9197590
# 27        67876.0     1918.0      9793185    842475    11624300
# 28        18013.0      333.0      7194244    176168    40837519
# 29        68620.0     1286.0      6378529    628890    10142523
# 30         5430.0      113.0      9098973     82284   110579574
# 31         2651.0       59.0      9278613     41456   223819585
# 32        65119.0     1157.0      5286832    607816     8698077
# 33         3330.0       51.0      4180938     25215   165814495
# 34        56708.0      528.0      3072096    352584     8713088
# 35        13083.0      234.0      5743512    154353    37210287
# 36        53020.0      969.0      5778608    639106     9041707
# 37        49278.0     1674.0      3891778    403568     9643436
# 38        43047.0      491.0      4954682    482320    10272593
# 39         3492.0       66.0      8673101     68720   126209420
# 40        41686.0      135.0     32641019   3273182     9972260
# 41        59054.0      755.0      3180572    467432     6804352
# 42        10816.0      186.0     14076117    400064    35184626
# 43        79281.0     1363.0      1977198    453360     4361210
# 44        59690.0     1472.0      2137775    391429     5461463
# 45         9687.0       36.0      6597363    202063    32649965
# 46        31492.0      218.0      5025044    531909     9447182
# 47        16555.0      901.0      1043263     58524    17826293
# 48         9319.0      102.0      2199950     74588    29494729
# 49        68560.0      904.0      2860823    718098     3983888
# 50        38599.0     1577.0      1778810    257340     6912303
# 51        21621.0     1005.0       764495     64887    11782012
# 52        60448.0     1375.0      1396129    341537     4087784
# 53        22319.0      292.0      1233986    112976    10922503
# 54        20046.0      695.0      1011915     85011    11903400
# 55        23257.0      319.0      2663151    261045    10201873
# 56        45011.0      895.0      3656842    734957     4975586
# 57        11586.0      149.0      7822859    413240    18930569
# 58        37165.0      410.0     18364726   3162934     5806231
# 59        20164.0      659.0      5638039    542750    10387913
# 60        40544.0      556.0       717791    140029     5126029
# 61        47071.0      265.0      1867338    432878     4313777
# 62        75270.0     1240.0      2182242    809444     2695978
# 63        38667.0      419.0      1245509    240344     5182186
# 64        48783.0     1030.0       748683    185893     4027499
# 65        94472.0     1878.0       950058    456949     2079135
# 66         1811.0      107.0      1000000      9648   103652051
# 67         9898.0      358.0       953641     52566    18141854
# 68        59048.0     1089.0       755348    254578     2967055
# 69        17403.0      428.0       461743     46118    10012312
# 70        23912.0      467.0       786625    109367     7192549
# 71         1440.0       21.0      2192311     18753   116901593
# 72        59793.0       94.0      1591056    566655     2807805
# 73          760.0        9.0      1601396      7640   209616674
# 74        27879.0      307.0      1550000    298365     5194982
# 75         5050.0       49.0      2962352    104380    28380376
# 76         2599.0       59.0      2505402     45836    54660305
# 77        20286.0      331.0       762485    109943     6935250
# 78        42410.0     1636.0       694132    212486     3266726
# 79        73380.0      272.0      3226434   1852557     1741611
# 80         2580.0       68.0           -1        -1    44391836
# 81        39716.0      685.0       490642    170621     2875632
# 82         2009.0       35.0      1340657     24564    54578543
# 83        52008.0     1549.0       548210    263143     2083315
# 84         1818.0       32.0      6902984    134562    51299567
# 85        48616.0      911.0      1600474    855060     1871769
# 86         2752.0       21.0       929189     29484    31515269
# 87        13127.0      224.0       770225    116740     6597767
# 88         4021.0       24.0      2194290    102179    21474981
# 89         4425.0       61.0      1138369     60766    18733742
# 90       128642.0     1739.0       296858    472613      628121
# 91         2374.0       18.0      1377915     40765    33801081
# 92        58388.0      504.0       994902    749654     1327149
# 93        14033.0      116.0      3910562    717490     5450339
# 94        18819.0      191.0      1079088    309904     3482010
# 95        11378.0      140.0      3512031    633181     5546645
# 96         1974.0       22.0       443786     13933    31850349
# 97         9455.0      295.0       789516    121302     6508699
# 98        10210.0        5.0      7805264   1326992     5881924
# 99         5088.0       31.0      2558296    225961    11321853
# 100       89775.0     1055.0      2194489   3467136      632940
# 101        1414.0       62.0       312655      7910    39525709
# 102         867.0        7.0       894547     19147    46720520
# 103       15681.0      173.0       314993    122454     2572331
# 104       31029.0      192.0      2343468   1931333     1213394
# 105        1363.0       21.0       905000     33524    26995539
# 106        2420.0       99.0       353701     23563    15010955
# 107        2114.0       55.0       404315     23722    17043964
# 108        1323.0        8.0       445505     16609    26822819
# 109       13805.0      173.0       846715    355163     2384019
# 110        1671.0       55.0       204623     10512    19466178
# 111        1131.0       35.0     14690475    571556    25702606
# 112         646.0       43.0           -1        -1    44546549
# 113        9247.0      155.0       231845     78061     2970053
# 114         292.0        8.0           -1        -1    91408877
# 115         379.0        1.0      1588637     22721    69920493
# 116       56170.0      757.0       733474   1658123      442352
# 117         629.0       15.0       402283     11987    33559691
# 118       38450.0      117.0       559713   1023153      547047
# 119         715.0       11.0       122057      4332    28175252
# 120        1502.0       21.0      1043645     79240    13170723
# 121       65580.0      500.0        26355     93449      282024
# 122       66402.0      465.0       143569    517746      277296
# 123        3669.0       93.0       181628     38377     4732767
# 124       14713.0      563.0       154809    132497     1168400
# 125        1264.0        7.0       147603     11036    13374921
# 126       54921.0      286.0       153467    504914      303947
# 127         906.0       60.0           -1        -1    17790059
# 128        7082.0       40.0       556935    246268     2261498
# 129       28254.0      275.0       125300    223700      560126
# 130       15340.0       79.0        98785    109798      899699
# 131        1095.0       22.0        54379      4730    11497743
# 132       30666.0      785.0        88587    220060      402558
# 133         572.0        7.0           -1        -1    21292809
# 134        1475.0       27.0      9296529   1233170     7538725
# 135      143361.0     1448.0       193595   2502844       77350
# 136        4886.0      143.0        62593     29060     2153905
# 137       25362.0      405.0       135623    338913      400171
# 138        1636.0       23.0        92500     16487     5610530
# 139       15223.0      296.0        42033     71214      590238
# 140         786.0        9.0       116018     10282    11283640
# 141       11211.0      259.0        71427     90510      789161
# 142       21833.0      467.0        70352    177737      395821
# 143         417.0       17.0       157586      7632    20646938
# 144         530.0       20.0           -1        -1    16194484
# 145       76365.0      719.0       110382   1030856      107078
# 146        5515.0      100.0        99115     70665     1402605
# 147         913.0       11.0       247179     29388     8410866
# 148       18472.0      125.0       108633    289639      375064
# 149         979.0       26.0           -1        -1     6678549
# 150        4442.0       67.0       101517     70782     1434218
# 151         514.0        7.0       514906     41729    12339141
# 152        6194.0       63.0       118477    118735      997830
# 153       17700.0       85.0       508716   1484158      342764
# 154        1028.0       13.0        37104      7592     4887137
# 155         195.0        7.0        82995      3347    24799309
# 156       29352.0      134.0        53539    325358      164554
# 157        1946.0       62.0        45147     18332     2462792
# 158      126321.0     2761.0       194538   5775383       33684
# 159         252.0        9.0           -1        -1    16745966
# 160       23108.0      492.0       388235   2218968      174962
# 161      117245.0     2266.0        45513   1339406       33980
# 162         485.0       10.0       116448     14398     8087641
# 163       21183.0      250.0        33074    179551      184204
# 164        4087.0      165.0           -1        -1      882231
# 165        1017.0        0.9      1934966    583809     3314382
# 166       11588.0      129.0       130960    455328      287617
# 167        1660.0       25.0        54011     27010     1999675
# 168       30699.0      152.0         5200     52650       98765
# 169         822.0        2.0        23693      6618     3580015
# 170       67900.0     1440.0        28293    740596       38203
# 171          85.0       22.0        17404       575    30273670
# 172          26.0        0.4      2598753     26534    97939424
# 173         482.0        5.0      1786705    357191     5002100
# 174         193.0        0.2        90019      7420    12131153
# 175       55712.0      384.0        17366    444416       39076
# 176       48044.0      625.0        21103    488382       43210
# 177       51936.0      659.0        51953   1317501       39433
# 178         394.0       17.0        76815     14949     5138636
# 179        8908.0      144.0        11592     52231      221938
# 180         184.0        2.0        47490      5240     9062720
# 181       14957.0       72.0        37714    339210      111182
# 182       40162.0      307.0        22204    567630       39117
# 183          63.0       -1.0       534562     31673    16877329
# 184          41.0        0.4       444634     18646    23846445
# 185       11155.0      293.0        36419    426742       85342
# 186        1116.0        1.0       544778    700741      777431
# 187        8753.0      223.0        16075    163223       98485
# 188       11655.0      193.0       179210   2884947       62119
# 189       13472.0       20.0       234051   4777429       48991
# 190         503.0        8.0       289552    227417     1273221
# 191       64457.0      101.0        19114   1931097        9898
# 192       22243.0      189.0         7178    271997       26390
# 193           8.0        0.3           -1        -1    60889852
# 194        6943.0       30.0        75560   1140511       66251
# 195         434.0        7.0       107803    244811      440352
# 196        5038.0       33.0        13223    435411       30369
# 197        2094.0       -1.0        12122    168107       72109
# 198         106.0       -1.0        22857     17114     1335586
# 199         244.0       -1.0        23793     82793      287380
# 200          73.0        2.0        32164     35702      900905
# 201       15216.0       -1.0         7040   1983657        3549
# 202          73.0       -1.0         4369      6666      655394
# 203           6.0       -1.0       119288     16235     7347794
# 204       33666.0       -1.0           -1        -1         802
# 205        4005.0      200.0          947    189628        4994
# 206        1711.0       -1.0         1202    108269       11102
# 207          26.0       -1.0         4500      6444      698349
# 208          16.0        2.0           -1        -1      607335
# 209          15.0       -1.0           -1        -1      199319
# 210          10.0       -1.0          470      1506      312033
# 211       15157.1      336.3           -1        -1          -1
#
#              Continent  %Inc Cases  %Inc Deaths  %Inc Recovered
# 0                  All    0.329051     0.345974        0.428193
# 1        North America    0.186846     0.315220        0.485467
# 2                 Asia    0.149590     0.071483        0.184454
# 3        South America    0.625051     0.727562        0.618680
# 4               Europe    0.217503     0.374127        0.252557
# 5               Europe    0.136344     0.185101        1.125022
# 6               Europe    0.592495     0.353859        0.539361
# 7               Europe    0.126794     0.405705        0.442865
# 8               Europe    0.636840     0.374208        0.515479
# 9                 Asia    0.489957     0.226337        0.327152
# 10              Europe    0.271403     0.387772        0.375065
# 11       South America    0.153831     0.128552        0.130883
# 12       South America    0.337974     0.246000        0.258153
# 13       North America    0.088102     0.167083        0.332041
# 14              Europe    0.549630     0.618435        0.616622
# 15                Asia    0.501243     0.133077        0.508595
# 16              Africa    0.065082     0.202334        0.154887
# 17              Europe    0.231267     0.279371        0.081302
# 18                Asia    0.458669     0.556188        0.619055
# 19       South America    0.402602     0.394494        0.453315
# 20              Europe    0.792965     0.929084        0.033657
# 21              Europe    0.380517     0.351825             NaN
# 22       North America    0.315606     0.125538        0.350164
# 23       South America    0.408650     0.089699        0.509404
# 24              Europe    0.597090     0.441679        0.728345
# 25              Europe    0.104400     0.180777        0.254965
# 26                Asia    0.454184     0.303388        0.403822
# 27              Europe    0.141570     0.139063        0.132492
# 28                Asia    0.626677     0.161551        0.552568
# 29              Europe   -0.000144     0.260696             NaN
# 30                Asia    0.444350     0.055875        0.031314
# 31                Asia    0.227988     0.406596        0.596819
# 32              Europe    0.243286     0.089419       -0.000192
# 33                Asia    0.165191     0.153139        0.243198
# 34              Europe    0.926117     0.434877       -0.000250
# 35              Africa    0.104348     0.138010        0.140319
# 36              Europe    0.502930     0.285486        0.449399
# 37              Europe    1.366562     0.978571        0.649661
# 38                Asia    1.599269     1.169243        1.071701
# 39                Asia    0.154083     0.554284        0.245324
# 40                Asia    0.570837     0.743494        0.450013
# 41                Asia    0.980275     0.876510        0.646795
# 42                Asia    0.102477     0.076464        0.082405
# 43       North America    0.151261     0.168237        0.236032
# 44              Europe    0.677008     1.443325       -0.000392
# 45                Asia    0.404719     0.758853        0.791217
# 46              Europe    0.360655     0.389294        0.295783
# 47       South America    0.168071     0.161802       -0.000391
# 48                Asia    0.021465     0.033201        0.022141
# 49                Asia    0.050890     0.277701        0.048312
# 50              Europe    1.312569     1.265823        1.564468
# 51       South America    0.181757     0.185732        0.383920
# 52              Europe    0.198706     0.338018        0.194859
# 53       North America    0.103373     0.376058        0.281985
# 54              Africa    0.249777     0.520077        1.063477
# 55                Asia    0.125179     0.092308        0.054803
# 56              Europe    0.136633     0.673854       -0.004280
# 57                Asia    0.260344    -0.035474        0.228916
# 58              Europe    0.244218    -0.041999        0.285339
# 59              Europe    1.518653     0.672220        2.000312
# 60       North America    0.178991     0.245787        0.093542
# 61                Asia    0.569796     0.701139        0.555358
# 62              Europe    0.240482     0.179480        0.436346
# 63                Asia    0.912258     0.599078        0.906126
# 64              Europe    0.444331     0.506024        0.519230
# 65              Europe    0.376742     0.179303        0.490339
# 66              Africa    0.331352     0.397040        0.298102
# 67       North America    0.441628     0.215617        0.350820
# 68                Asia    0.103882     0.216584        0.086011
# 69       North America    0.294990     0.537007        0.141000
# 70       South America    1.235573     0.505952        0.847487
# 71              Africa    0.714052     0.367197        0.639997
# 72                Asia    0.280544     0.378788        0.199857
# 73              Africa    0.217266     0.301811        0.398401
# 74                Asia    0.294826     0.187852        0.237769
# 75       South America    0.381661     0.571837        0.406237
# 76                Asia    0.009855    -0.031250        0.017464
# 77              Africa    0.732116     0.391815        0.878111
# 78              Europe    0.902975     0.898036        0.348344
# 79                Asia    0.426448     0.210970        0.509471
# 80              Africa    0.140559     0.132363        0.166417
# 81              Europe    0.550745     0.660234        1.168212
# 82              Africa    0.436872     0.371156        0.128795
# 83              Europe    0.803876     0.681537        0.429964
# 84                Asia    0.478218     0.182371        0.507747
# 85              Europe    0.518698     0.351906        0.797359
# 86              Africa    0.313592     1.371951        0.426820
# 87                Asia    0.026557     0.135593        0.037079
# 88                Asia    0.352084     0.782779        0.290020
# 89              Africa    0.291929     0.439754        0.557085
# 90              Europe    0.757398     0.641026        0.723304
# 91                Asia    0.034892    -0.160772        0.030403
# 92              Europe    1.685401     0.298954        2.735727
# 93              Europe    0.933529    -0.158228       -0.001515
# 94       South America    1.262075     1.201201        1.349315
# 95              Europe    0.931707     0.257732       -0.002174
# 96              Africa    0.284660     0.285714        2.378009
# 97       North America    0.229123     0.416017        0.388212
# 98                Asia    0.009991    -3.448276        0.008347
# 99       North America    1.807072     0.568182        1.680832
# 100             Europe    0.255183     0.748503        0.048812
# 101               Asia    0.046517    -0.040800        0.014167
# 102             Africa    0.027167    -0.299401        0.066335
# 103             Africa    0.371867     1.126126        0.831288
# 104               Asia    1.115538    -0.429185       -0.048614
# 105             Africa   -0.002718    -0.176678       -0.003036
# 106             Africa    0.088103     0.134318        0.138565
# 107             Africa    0.221982     0.537634        0.862622
# 108             Africa    0.411534     0.970874        0.249377
# 109             Africa   -0.003038    -0.242131       -0.003602
# 110             Africa    0.181382     0.372439        2.473513
# 111  Australia/Oceania    0.051616    -0.110011        0.034346
# 112             Africa   -0.003476    -0.052219       -0.004298
# 113      North America    2.042600     1.304348        1.014046
# 114             Africa    0.213611    -0.140449       -0.004458
# 115               Asia    0.226407    -1.176471        0.286256
# 116             Europe    0.998108     0.298507        1.815896
# 117             Africa    0.028417     0.193798        0.101642
# 118               Asia    0.546734    -1.562500        0.949642
# 119             Africa   -0.004962    -0.333333       -0.005117
# 120             Africa    0.606704     0.740741        0.676537
# 121  Australia/Oceania    0.070289    -0.709220       -0.020653
# 122             Africa    0.532233     0.775194       -0.033738
# 123             Africa    0.143968    -0.226244        0.161532
# 124             Africa    0.017451    -0.151976        0.679700
# 125             Africa   -0.005913    -1.030928       -0.006563
# 126      South America   -0.005991    -1.149425       -0.010005
# 127               Asia    0.465347     0.558659        0.825349
# 128             Africa   -0.006244    -1.098901       -0.007119
# 129             Africa    0.126374    -0.649351        0.171515
# 130             Africa    4.898196    16.901408        3.495036
# 131      North America    0.460537    -0.400000        1.394602
# 132      North America    0.081004     0.316456        0.259262
# 133             Africa    0.049233    -0.699301        0.370995
# 134               Asia    0.188832    -0.495050        0.234500
# 135             Europe    0.180359    -0.892857        0.224614
# 136             Africa    0.019002     0.323625       -0.025497
# 137      North America   -0.009853    -0.617284       -0.044603
# 138             Africa   -0.010894    -0.763359       -0.013308
# 139      South America    0.055648    -0.571429        0.164958
# 140             Africa   -0.011274    -0.980392       -0.020350
# 141      South America    0.373008     0.490196        0.353659
# 142      North America    0.011571     1.081081        0.240545
# 143             Africa   -0.011610    -0.279330       -0.015504
# 144             Africa    1.620613     3.761755        2.455966
# 145      North America    0.819371    -1.298701        0.823515
# 146      North America   -0.012927    -0.714286       -0.013328
# 147             Africa    1.067708    -1.086957        1.857585
# 148      North America    1.587760     2.127660       -1.020408
# 149      North America    0.734282     0.571429       -0.023669
# 150             Africa   -0.015696    -1.041667       -0.017425
# 151             Africa   -0.015778    -1.234568       -0.018577
# 152             Africa    0.388287    -1.587302        0.084175
# 153             Europe    0.049448    -3.448276        0.033212
# 154             Africa    0.039817    -1.587302       -0.020325
# 155             Africa    0.144778    -0.564972        0.181200
# 156      North America    0.351967    -4.545455        0.106792
# 157             Africa   -0.020868    -0.653595       -0.023793
# 158             Europe    0.141011    -1.075269        0.048356
# 159             Africa    0.498339     1.351351        0.912997
# 160             Europe    0.024734    -1.162791        0.252653
# 161             Europe    1.154618     1.298701        0.607463
# 162             Africa    0.025497    -1.265823        0.729661
# 163      North America    0.794464    -2.173913        0.806676
# 164             Africa   -0.027732    -0.684932       -0.029180
# 165               Asia    1.067616   -33.333333        6.401447
# 166      North America    0.900090    -2.702703        2.332762
# 167             Africa    0.210907    -2.040816        0.558451
# 168             Africa    1.055409    -6.666667        2.349591
# 169             Africa   -0.033967   -14.285714       -0.041051
# 170             Europe    0.077101     1.818182       -0.039698
# 171               Asia    1.585460     0.152905        0.275672
# 172               Asia    0.079177    -2.857143        4.191617
# 173  Australia/Oceania    0.166044    -3.846154        0.130208
# 174             Africa    0.213767   -33.333333       -0.129366
# 175      North America   -0.045935    -6.666667       -0.049505
# 176      North America    0.096339    -3.703704        0.147710
# 177             Europe    0.976562    -3.846154        1.016586
# 178             Africa    0.098717    -1.176471        0.316122
# 179             Africa    0.809307    -3.125000        3.941783
# 180  Australia/Oceania   -0.059880    -6.250000       -0.118203
# 181      North America   -0.060132   -12.500000        6.636364
# 182      North America   -0.063654    -8.333333       -0.071480
# 183               Asia    4.622642   100.000000        3.903346
# 184               Asia    0.102354   -10.000000       -0.107296
# 185             Europe    9.138655    -4.000000       -0.239808
# 186               Asia   -0.115207  -100.000000       -0.115473
# 187      North America    1.624130     4.545455        9.890110
# 188      North America   -0.138122    -8.333333       -0.144928
# 189             Europe   -0.151515  -100.000000       -0.152207
# 190             Africa   -0.156006   -10.000000       -0.170068
# 191      North America   -0.156740  -100.000000       -0.216450
# 192      North America    8.006814   -20.000000        2.207506
# 193             Africa   -0.196464    -4.761905       -0.546448
# 194      North America    1.956522   -50.000000       -0.234742
# 195               Asia    0.523560   -33.333333        0.546448
# 196      North America   -0.653595  -100.000000       -0.763359
# 197      North America    4.635762   100.000000        5.797101
# 198               Asia   14.084507   100.000000       -1.063830
# 199  Australia/Oceania    4.285714   100.000000       -1.724138
# 200  Australia/Oceania   -1.515152   -50.000000       -1.754386
# 201      South America   -1.851852   100.000000       -1.960784
# 202               Asia   -2.083333   100.000000       -2.127660
# 203               Asia   -2.127660   100.000000       -2.380952
# 204             Europe   -3.703704   100.000000       -6.666667
# 205      North America   -5.000000  -100.000000       -7.142857
# 206  Australia/Oceania   15.789474   100.000000      -14.285714
# 207  Australia/Oceania   -5.555556   100.000000       -7.142857
# 208             Africa  -10.000000  -100.000000      -12.500000
# 209  Australia/Oceania  -33.333333   100.000000      -50.000000
# 210  Australia/Oceania  -33.333333   100.000000     -100.000000
# 211                All    0.329051     0.345974        0.428193

# %%
EXPORT = True
today = datetime.now()
if EXPORT:
    today = date.today()
    df.to_csv(f'covid_stats_{today.year}_{today.month}_{today.day-1}')
    print("Dataset is %.2f MB" % (df.memory_usage(deep=True).sum()/1000000))
# Out:
# Dataset is 0.05 MB

# %%
cases_df = df[["Total Recovered", "Active Cases", "Total Deaths"]].loc[0]
pd.DataFrame(cases_df).T.plot.bar(stacked=True, figsize=(16, 12))
plt.xticks(np.arange(0, 0, 1)) # No Ticks
plt.title(f"Total Number of Cases, Recoveries, and Deaths on {yesterday_str}", fontsize=20)
plt.legend(prop={"size": 12})

prev = 0
total = cases_df.sum()
for num in cases_df.cumsum():
    val = round((num-prev)/total*100, 3)
    plt.annotate(f"{val}% ({num-prev})", (0, (num-prev)/2+prev), fontsize=14, ha='center')
    prev = num
plt.show()

# %%
new_df = df[["New Cases", "New Recovered", "New Deaths"]].loc[0]
pd.DataFrame(new_df).T.plot.bar(stacked=True, figsize=(16, 12))
plt.xticks(np.arange(0, 0, 1)) # No Ticks
plt.title(f"New Cases, Recoveries, and Deaths on {yesterday_str}", fontsize=20)
plt.legend(prop={"size": 12})

prev = 0
total = new_df.sum()
for num in new_df.cumsum():
    val = round((num-prev)/total*100, 3)
    plt.annotate(f"{val}% ({round(num-prev)})", (0, (num-prev)/2+prev), fontsize=14, ha='center')
    prev = num
plt.show()

# %%
pinc_df = df[["%Inc Cases", "%Inc Recovered", "%Inc Deaths"]].loc[0]
pd.DataFrame(pinc_df).T.plot.bar(figsize=(16, 12))
plt.xticks(np.arange(0, 0, 1)) # No Ticks
plt.title(f"Percentage Increase in Cases, Recoveries, and Deaths on {yesterday_str}", fontsize=20)
plt.ylabel("Percentage", fontsize=14)
plt.legend(prop={"size": 12})
plt.show()

# %%
continent_df = df.groupby('Continent').sum().drop('All')
continent_df = continent_df.reset_index()
continent_df
# Out:
#            Continent  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0             Africa      4011465     8440.0        106582       269.0
# 1               Asia     25607911    81852.0        401114       803.0
# 2  Australia/Oceania        51814       33.0          1089       -10.0
# 3             Europe     35373089   139436.0        841256      3343.0
# 4      North America     34219542    65019.0        780857      2121.0
# 5      South America     18778739    93936.0        485645      2451.0
#
#    Total Recovered  New Recovered  Active Cases  Serious/Critical  \
# 0          3578347        12756.0      326536.0              2557
# 1         24009840        72981.0     1196953.0             22349
# 2            34335            4.0       16385.0                -5
# 3         24984505       121708.0     7752109.0             26504
# 4         24217819       112213.0     9220865.0             19234
# 5         16902022        82119.0     1391071.0             19021
#
#    Tot Cases/1M  Deaths/1M  Total Tests  Tests/1M  Population  %Inc Cases  \
# 0      348458.0     5649.5     35052860   3405282  1362431939    7.465333
# 1      880759.0     8950.7    459886994  20070502  3183724638   31.615229
# 2       69456.0      539.0     16613153   1262149    42458538  -53.434117
# 3     2713692.0    52289.0    536691684  48691591   747941517   29.552454
# 4      849320.0    12680.0    413104098  15177832   592030484   21.759250
# 5      413074.0     9614.0     72891102   4583065   433196987    3.728058
#
#    %Inc Deaths  %Inc Recovered
# 0  -160.112527       17.257784
# 1   223.852827       22.278871
# 2   439.084615     -174.881397
# 3     6.045140       15.126790
# 4  -308.908206       26.271759
# 5   102.982174        3.504830

# %%
cases_vis_list = ['Total Cases', 'Active Cases', 'New Cases', 'Serious/Critical', 'Tot Cases/1M']
deaths_vis_list = ['Total Deaths', 'New Deaths', 'Deaths/1M']
recovered_vis_list = ['Total Recovered', 'New Recovered']
tests_vis_list = ['Total Tests', 'Tests/1M']
essentials = [['Total Cases', 'Active Cases', 'New Cases'], ['Total Deaths', 'New Deaths'], ['Total Recovered', 'New Recovered']]

# %%
def continent_visualization(vis_list):
    for label in vis_list:
        pd.DataFrame(continent_df[label]).T.plot.bar(stacked=True, figsize=(16, 12))
        plt.title(f"{label} at the end of {yesterday_str}", fontsize=24)
        plt.xlabel("")
        plt.ylabel(f"{label}", fontsize=16)
        plt.yticks(fontsize=16)
        plt.legend(continent_df['Continent'])

        prev = 0
        total = continent_df[label].sum()
        for num in continent_df[label].cumsum():
            val = round((num-prev)/total*100, 3)
            if val < 1:
                continue
            plt.annotate(f"{val}% ({round(num-prev)})", (0, (num-prev)/2+prev), fontsize=14, ha='center')
            prev = num

        plt.show()
        gc.collect()

# %%
continent_visualization(cases_vis_list)

# %%
continent_visualization(deaths_vis_list)

# %%
continent_visualization(tests_vis_list)

# %%
def continent_visualization2(index, label):
    continent_df.plot.bar(x="Continent", y=essentials[index], stacked=True, figsize=(16, 12))
    plt.title(f"{label} at the end of {yesterday_str}", fontsize=24)
    plt.xlabel("")
    plt.ylabel(f"{label}", fontsize=16)
    plt.yticks(fontsize=16)
    plt.show()
    gc.collect()

# %%
continent_visualization2(0, "Total Cases")

# %%
continent_visualization2(1, "Total Deaths")

# %%
continent_visualization2(2, "Total Recoveries")

# %%
df = df.drop([len(df)-1])
country_df = df.drop([0])

# %%
country_l = country_df.columns[1:14]

fig = go.Figure()
c = 0
for i in country_df.index:
    if c<4:
        fig.add_trace(go.Bar(name=country_df['Country'][i], x=country_l, y=country_df.loc[i][1:14]))
    else:
        break
    c += 1
    
fig.update_layout(title={'text': '4 Countries with Most COVID Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", yaxis_type="log", xaxis_tickangle=-90)
fig.show()
# Out:
# <div>                            <div id="71f2d578-31f2-4b15-a1c7-61461598d11b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71f2d578-31f2-4b15-a1c7-61461598d11b")) {                    Plotly.newPlot(                        "71f2d578-31f2-4b15-a1c7-61461598d11b",                        [{"name": "USA", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [29801506, 55683.0, 540574, 1704.0, 20549678, 99762.0, 8711254.0, 12715, 89673.0, 1627.0, 371894718, 1119032, 332336197]}, {"name": "India", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [11261470, 16846.0, 158079, 113.0, 10917624, 20138.0, 185767.0, 8944, 8106.0, 114.0, 222716796, 160308, 1389308662]}, {"name": "Brazil", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [11125017, 69537.0, 268568, 1954.0, 9843218, 60898.0, 1013231.0, 8318, 52084.0, 1257.0, 28600000, 133897, 213596922]}, {"name": "Russia", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [4342474, 9445.0, 89809, 336.0, 3932177, 9931.0, 320488.0, 2300, 29748.0, 615.0, 113700000, 778887, 145977558]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidt ...

# %%
inc_l = country_df.columns[15:]
inc_df = country_df.sort_values("%Inc Cases", ascending=False)
fig = go.Figure()
c = 0
for i in inc_df.index:
    if i > 50:
        continue
    if c < 4:
        fig.add_trace(go.Bar(name=country_df['Country'][i], x=inc_l, y=inc_df.loc[i][15:]))
    else:
        break
    c += 1
    
fig.update_layout(title={'text': '4 Countries with Highest Increase in COVID Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", xaxis_tickangle=0)
fig.show()
# Out:
# <div>                            <div id="d489573e-d4c5-4a52-93aa-ec8de93b60eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d489573e-d4c5-4a52-93aa-ec8de93b60eb")) {                    Plotly.newPlot(                        "d489573e-d4c5-4a52-93aa-ec8de93b60eb",                        [{"name": "Jordan", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [1.5992691123061404, 1.1692429647245344, 1.071700605628026]}, {"name": "Hungary", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [1.3665623612446787, 0.9785705437879352, 0.6496610079481687]}, {"name": "Bulgaria", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [1.312569104776897, 1.2658227848101267, 1.5644682279167699]}, {"name": "Lebanon", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [0.9802750444222127, 0.876509544215037, 0.646794776083842]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f92 ...

# %%
country_labels = country_df.columns[1:14]

def country_visualization(continent):
    buttons_list = []
    base_list = [False for i in range(len(country_df))]
    c = 0
    for i in country_df.index:
        if country_df.loc[i]['Continent'] != continent:
            continue
        tmp_list = base_list.copy()
        tmp_list[c] = True
        c += 1
        buttons_list.append(dict(
                    args=[{"visible": tmp_list}],
                    label=country_df.loc[i]['Country'],
                    method="update"
                ))


    fig = go.Figure()
    c = 0
    for i in country_df.index:
        if country_df.loc[i]['Continent'] != continent:
            continue
        fig.add_trace(go.Bar(name=country_df.loc[i]['Country'], x=country_labels, y=country_df.loc[i][1:14], visible=False if c != 0 else True))
        c += 1
        
    fig.update_layout(
        updatemenus=[
            dict(
                buttons=buttons_list,
                direction="down",
                pad={"r": 10, "t": 10},
                showactive=True,
                x=0.1,
                xanchor="left",
                y=1.1,
                yanchor="top"
            ),
        ]
    )

    fig.update_layout(title={'text': '%s COVID-19 Cases Search on %s' % (continent, yesterday_str), 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_type="log", xaxis_tickangle=-90)
    fig.show()

# %%
country_visualization('Africa')
# Out:
# <div>                            <div id="b22484bc-220a-4825-b7a6-4163525ba7e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b22484bc-220a-4825-b7a6-4163525ba7e0")) {                    Plotly.newPlot(                        "b22484bc-220a-4825-b7a6-4163525ba7e0",                        [{"name": "South Africa", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1522697, 991.0, 50906, 103.0, 1444282, 2237.0, 27509.0, 546, 25454.0, 851.0, 9299884, 155462, 59820794]}, {"name": "Morocco", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [486833, 508.0, 8695, 12.0, 473208, 664.0, 4930.0, 272, 13083.0, 234.0, 5743512, 154353, 37210287]}, {"name": "Tunisia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [238613, 596.0, 8268, 43.0, 205176, 2182.0, 25169.0, 273, 20046.0, 695.0, 1011915, 85011, 11903400]}, {"name": "Egypt", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [187716, 622.0, 11082, 44.0, 144917, 432.0, 31717.0, 90, 1811.0, 107.0, 1000000, 9648, 103652051]}, {"name": "Ethiopia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [168335, 1202.0, 2451, 9.0, 139532, 893.0, 26352.0, 427, 1440.0, 21.0, 2192311, 18753, 116901593]}, {"name": "Nigeria", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [159252, 346.0, 1988, 6.0, 139056, 554.0, 18208.0, 10, 760.0, 9.0, 1601396, 7640, 209616674]}, {"name": "Libya", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [140688, 1030.0, 2297, 9.0, 128002, 1124.0, 10389.0, -1, 20286.0, 331.0, 762485, 109943, 6935250]}, {"name": "Algeria", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [114543, 161.0, 3022, 4.0, 79319, 132.0, 32202.0, 19, 2580.0, 68.0, -1, -1, 44391836]}, {"name": "Kenya", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [109643, 479.0, 1886, 7.0, 87736, 113.0, 20021.0, 86, 2009.0, 35.0, 1340657, 24564, 54578543]}, {"name": "Ghana", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Case ...

# %%
country_visualization('Asia')
# Out:
# <div>                            <div id="2074b806-088c-48a6-ab75-f592a8aa0e20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2074b806-088c-48a6-ab75-f592a8aa0e20")) {                    Plotly.newPlot(                        "2074b806-088c-48a6-ab75-f592a8aa0e20",                        [{"name": "India", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [11261470, 16846.0, 158079, 113.0, 10917624, 20138.0, 185767.0, 8944, 8106.0, 114.0, 222716796, 160308, 1389308662]}, {"name": "Turkey", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [2807387, 13755.0, 29160, 66.0, 2640669, 8639.0, 137558.0, 1289, 33043.0, 343.0, 34403108, 404928, 84961145]}, {"name": "Iran", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1706559, 8554.0, 60867, 81.0, 1456759, 7409.0, 188933.0, 3811, 20141.0, 718.0, 11274630, 133067, 84729135]}, {"name": "Indonesia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1392945, 6389.0, 37757, 210.0, 1210877, 7496.0, 144311.0, -1, 5056.0, 137.0, 11266592, 40894, 275506383]}, {"name": "Israel", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [808262, 3671.0, 5933, 18.0, 764445, 3087.0, 37884.0, 664, 87878.0, 645.0, 12581283, 1367889, 9197590]}, {"name": "Iraq", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [735626, 4610.0, 13618, 22.0, 668153, 3692.0, 53855.0, 428, 18013.0, 333.0, 7194244, 176168, 40837519]}, {"name": "Philippines", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [600428, 2668.0, 12528, 7.0, 546078, 171.0, 41822.0, 785, 5430.0, 113.0, 9098973, 82284, 110579574]}, {"name": "Pakistan", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [593453, 1353.0, 13281, 54.0, 563823, 3365.0, 16349.0, 1644, 2651.0, 59.0, 9278613, 41456, 223819585]}, {"name": "Bangladesh", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [552087, 912.0, 8489, 13.0, 505349, 1229.0, 38249.0, -1, 3330.0, 51.0, 4180938, 25215, 165814495]}, {"name": "Jordan", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total ...

# %%
country_visualization('Australia/Oceania')
# Out:
# <div>                            <div id="df05af96-3ef5-444d-b4de-1bbb17d1b2a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df05af96-3ef5-444d-b4de-1bbb17d1b2a0")) {                    Plotly.newPlot(                        "df05af96-3ef5-444d-b4de-1bbb17d1b2a0",                        [{"name": "Australia", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [29061, 15.0, 909, -1.0, 26204, 9.0, 1948.0, -1, 1131.0, 35.0, 14690475, 571556, 25702606]}, {"name": "French Polynesia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [18495, 13.0, 141, -1.0, 4842, -1.0, 13512.0, 2, 65580.0, 500.0, 26355, 93449, 282024]}, {"name": "New Zealand", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [2409, 4.0, 26, -1.0, 2304, 3.0, 79.0, -1, 482.0, 5.0, 1786705, 357191, 5002100]}, {"name": "Papua New Guinea", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1670, -1.0, 16, -1.0, 846, -1.0, 808.0, -1, 184.0, 2.0, 47490, 5240, 9062720]}, {"name": "New Caledonia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [70, 3.0, -1, -1.0, 58, -1.0, 12.0, -1, 244.0, -1.0, 23793, 82793, 287380]}, {"name": "Fiji", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [66, -1.0, 2, -1.0, 57, -1.0, 7.0, -1, 73.0, 2.0, 32164, 35702, 900905]}, {"name": "Wallis and Futuna", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [19, 3.0, -1, -1.0, 7, -1.0, 12.0, 1, 1711.0, -1.0, 1202, 108269, 11102]}, {"name": "Solomon Islands", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [18, -1.0, -1, -1.0, 14, -1.0, 4.0, -1, 26.0, -1.0, 4500, 6444, 698349]}, {"name": "Samoa", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [3, -1.0, -1, -1.0, 2, -1.0, 1.0, -1, 15.0, -1.0, -1, -1, 199319]}, {"name": "Vanuatu", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [3, -1.0, -1, -1.0, 1, -1.0, 2.0, -1, 10.0, -1.0, 470, 1506, 31 ...

# %%
country_visualization('Europe')
# Out:
# <div>                            <div id="97b696df-9369-43d8-9e39-ae8544771928" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97b696df-9369-43d8-9e39-ae8544771928")) {                    Plotly.newPlot(                        "97b696df-9369-43d8-9e39-ae8544771928",                        [{"name": "Russia", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [4342474, 9445.0, 89809, 336.0, 3932177, 9931.0, 320488.0, 2300, 29748.0, 615.0, 113700000, 778887, 145977558]}, {"name": "UK", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [4228998, 5766.0, 124797, 231.0, 3315934, 37305.0, 788267.0, 1356, 62071.0, 1832.0, 98133566, 1440364, 68131084]}, {"name": "France", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [3932862, 23302.0, 89301, 316.0, 267539, 1443.0, 3576022.0, 3918, 60160.0, 1366.0, 55599261, 850494, 65372907]}, {"name": "Spain", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [3164983, 4013.0, 71727, 291.0, 2823433, 12504.0, 269823.0, 2358, 67675.0, 1534.0, 40292390, 861551, 46767250]}, {"name": "Italy", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [3101093, 19749.0, 100479, 376.0, 2521731, 12999.0, 478883.0, 2756, 51342.0, 1664.0, 42872865, 709809, 60400547]}, {"name": "Germany", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [2520609, 6841.0, 72981, 283.0, 2319600, 8700.0, 128028.0, 2848, 30019.0, 869.0, 45114160, 537277, 83968223]}, {"name": "Poland", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1811036, 9954.0, 45599, 282.0, 1503353, 9270.0, 262084.0, 1837, 47888.0, 1206.0, 10328276, 273104, 37818045]}, {"name": "Ukraine", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1410061, 3261.0, 27204, 76.0, 1199229, 975.0, 183628.0, 177, 32376.0, 625.0, 7062386, 162159, 43552328]}, {"name": "Czechia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1335999, 10594.0, 22280, 207.0, 1164688, 392.0, 149031.0, 1789, 124596.0, 2078.0, 8877876, 827955, 10722655]}, {"name": "Netherlands", "type": "bar", "visible": false, "x": ["Total Cases", "New Cas ...

# %%
country_visualization('North America')
# Out:
# <div>                            <div id="ddf00292-f530-4f86-ac84-4745d535a431" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddf00292-f530-4f86-ac84-4745d535a431")) {                    Plotly.newPlot(                        "ddf00292-f530-4f86-ac84-4745d535a431",                        [{"name": "USA", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [29801506, 55683.0, 540574, 1704.0, 20549678, 99762.0, 8711254.0, 12715, 89673.0, 1627.0, 371894718, 1119032, 332336197]}, {"name": "Mexico", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [2130477, 1877.0, 190923, 319.0, 1675996, 5565.0, 263558.0, 4798, 16406.0, 1470.0, 5626739, 43329, 129861409]}, {"name": "Canada", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [893518, 2820.0, 22304, 28.0, 841035, 2945.0, 30179.0, 549, 23533.0, 587.0, 25352166, 667703, 37969201]}, {"name": "Panama", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [345759, 523.0, 5944, 10.0, 333005, 786.0, 6810.0, 195, 79281.0, 1363.0, 1977198, 453360, 4361210]}, {"name": "Dominican Republic", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [243778, 252.0, 3191, 12.0, 198947, 561.0, 41640.0, 185, 22319.0, 292.0, 1233986, 112976, 10922503]}, {"name": "Costa Rica", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [207832, 372.0, 2848, 7.0, 188151, 176.0, 16833.0, 139, 40544.0, 556.0, 717791, 140029, 5126029]}, {"name": "Guatemala", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [179563, 793.0, 6493, 14.0, 165897, 582.0, 7173.0, 5, 9898.0, 358.0, 953641, 52566, 18141854]}, {"name": "Honduras", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [174243, 514.0, 4283, 23.0, 68085, 96.0, 101875.0, 416, 17403.0, 428.0, 461743, 46118, 10012312]}, {"name": "El Salvador", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [61539, 141.0, 1923, 8.0, 57958, 225.0, 1658.0, 53, 9455.0, 295.0, 789516, 121302, 6508699]}, {"name": "Cuba", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New R ...

# %%
country_visualization('South America')
# Out:
# <div>                            <div id="edf9bb73-6efb-4814-a8b0-d5361e64baf5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edf9bb73-6efb-4814-a8b0-d5361e64baf5")) {                    Plotly.newPlot(                        "edf9bb73-6efb-4814-a8b0-d5361e64baf5",                        [{"name": "Brazil", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [11125017, 69537.0, 268568, 1954.0, 9843218, 60898.0, 1013231.0, 8318, 52084.0, 1257.0, 28600000, 133897, 213596922]}, {"name": "Colombia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [2282372, 3511.0, 60676, 78.0, 2183635, 2858.0, 38061.0, 1982, 44530.0, 1184.0, 11784331, 229917, 51254665]}, {"name": "Argentina", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [2162001, 7307.0, 53252, 131.0, 1956591, 5051.0, 152158.0, 3525, 47537.0, 1171.0, 7791570, 171318, 45480270]}, {"name": "Peru", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1380023, 5556.0, 48163, 190.0, 1288067, 5839.0, 43793.0, 2192, 41459.0, 1447.0, 7986252, 239927, 33286198]}, {"name": "Chile", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [864064, 3531.0, 21182, 19.0, 814088, 4147.0, 28794.0, 1839, 44936.0, 1102.0, 9819159, 510649, 19228797]}, {"name": "Ecuador", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [295114, 496.0, 16069, 26.0, 256009, -1.0, 23036.0, 529, 16555.0, 901.0, 1043263, 58524, 17826293]}, {"name": "Bolivia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [254736, 463.0, 11845, 22.0, 199000, 764.0, 43891.0, 71, 21621.0, 1005.0, 764495, 64887, 11782012]}, {"name": "Paraguay", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [171985, 2125.0, 3360, 17.0, 142893, 1211.0, 25732.0, 324, 23912.0, 467.0, 786625, 109367, 7192549]}, {"name": "Venezuela", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [143321, 547.0, 1399, 8.0, 135389, 550.0, 6533.0, 139, 5050.0, 49.0, 2962352, 104380, 28380376]}, {"name": "Uruguay", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Re ...

# %%
bar_list = []
for i in country_df.index:
    bar_list.append(go.Bar(name=country_df['Country'][i], y=[country_df['Total Cases'][i]]))
    
fig = go.Figure(data=bar_list)
fig.update_layout(title={'text': 'Stacked Bar Chart of All Countries COVID-19 Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, barmode='stack', height=1200)
fig.show()
# Out:
# <div>                            <div id="cc7957ea-d068-4894-869c-cc0a5f1a2852" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc7957ea-d068-4894-869c-cc0a5f1a2852")) {                    Plotly.newPlot(                        "cc7957ea-d068-4894-869c-cc0a5f1a2852",                        [{"name": "USA", "type": "bar", "y": [29801506]}, {"name": "India", "type": "bar", "y": [11261470]}, {"name": "Brazil", "type": "bar", "y": [11125017]}, {"name": "Russia", "type": "bar", "y": [4342474]}, {"name": "UK", "type": "bar", "y": [4228998]}, {"name": "France", "type": "bar", "y": [3932862]}, {"name": "Spain", "type": "bar", "y": [3164983]}, {"name": "Italy", "type": "bar", "y": [3101093]}, {"name": "Turkey", "type": "bar", "y": [2807387]}, {"name": "Germany", "type": "bar", "y": [2520609]}, {"name": "Colombia", "type": "bar", "y": [2282372]}, {"name": "Argentina", "type": "bar", "y": [2162001]}, {"name": "Mexico", "type": "bar", "y": [2130477]}, {"name": "Poland", "type": "bar", "y": [1811036]}, {"name": "Iran", "type": "bar", "y": [1706559]}, {"name": "South Africa", "type": "bar", "y": [1522697]}, {"name": "Ukraine", "type": "bar", "y": [1410061]}, {"name": "Indonesia", "type": "bar", "y": [1392945]}, {"name": "Peru", "type": "bar", "y": [1380023]}, {"name": "Czechia", "type": "bar", "y": [1335999]}, {"name": "Netherlands", "type": "bar", "y": [1128202]}, {"name": "Canada", "type": "bar", "y": [893518]}, {"name": "Chile", "type": "bar", "y": [864064]}, {"name": "Romania", "type": "bar", "y": [835552]}, {"name": "Portugal", "type": "bar", "y": [811306]}, {"name": "Israel", "type": "bar", "y": [808262]}, {"name": "Belgium", "type": "bar", "y": [789008]}, {"name": "Iraq", "type": "bar", "y": [735626]}, {"name": "Sweden", "type": "bar", "y": [695975]}, {"name": "Philippines", "type": "bar", "y": [600428]}, {"name": "Pakistan", "type": "bar", "y": [593453]}, {"name": "Switzerland", "type": "bar", "y": [566412]}, {"name": "Bangladesh", "type": "bar", "y": [552087]}, {"name": "Serbia", "type": "bar", "y": [494106]}, {"name": "Morocco", "type": "bar", "y": [486833]}, {"name": "Austria", "type": "bar", "y": [479391]}, {"name": "Hungary", "type": "bar", "y": [475207]}, {"name": "Jordan", "type": "bar", "y": [442202]}, {"name": "Japan", "type": "bar", "y": [440671]}, {"name": "UAE", "type": "bar", "y": [415705]}, {"name": "Lebanon", "type": "bar", "y": [401826]}, {"name": "Saudi Arabia", "type": "bar", "y": [380572]}, {"name": "Panama", "type": "bar", "y": [345759]}, {"name": "Slovakia", "type": "bar", "y": [325993]}, {"name": "Malaysia", "type": "bar", "y": [316269]}, {"name": "Belarus", "type": "bar", "y": [297514]}, {"name": "Ecuador", "type": "bar", "y": [295114]}, {"name": "Nepal", "type": "bar", "y": [274869]}, {"name": "Georgia", "type": "bar", "y": [273137]}, {"name": "Bulgaria", "type": "bar", "y": [266805]}, {"name": "Bolivia", "type": "bar", "y": [254736]}, {"name": "Croatia", "type": "bar", "y": [247099]}, {"name": "Dominican Republic", "type": "bar", "y": [243778]}, {"name": "Tunisia", "type": "bar", "y": [238613]}, {"name": "Azerbaijan", "type": "bar", "y": [237260]}, {"name": "Ireland", "type": "bar", "y": [223957]}, {"name": "Kazakhstan", "type": "bar", "y": [219325]}, {"name": "Denmark", "type": "bar", "y": [215791]}, {"name": "Greece", "type": "bar", "y": [209462]}, {"name": "Costa Rica", "type": "bar", "y": [207832]}, {"name": "Kuwait", "type": "bar", "y": [203055]}, {"name": "Lithuania", "type": "bar", "y": [202926]}, {"name": "Palestine", "type": "bar", "y": [200382]}, {"name": "Moldova", "type": "bar", "y": [196475]}, {"name": "Slovenia", "type": "bar", "y": [196421]}, {"name": "Egypt", "type": "bar", "y": [187716]}, {"name": "Guatemala", "type": "bar", "y": [179563]}, {"name": "Armen ...

# %%
bar = go.Bar(x=country_df['Country'], y=country_df['Total Cases'], marker=dict(color=df['Total Cases'], colorscale='Reds', showscale=True))
fig = go.Figure(data=[bar])
fig.update_layout(title={'text': 'Number of COVID Cases by Country on %s, log scale' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_type="log", xaxis_tickangle=-90)
# Out:
# <div>                            <div id="64f31357-8c79-4b82-8390-7abaa96c17d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64f31357-8c79-4b82-8390-7abaa96c17d7")) {                    Plotly.newPlot(                        "64f31357-8c79-4b82-8390-7abaa96c17d7",                        [{"marker": {"color": [118146858, 29801506, 11261470, 11125017, 4342474, 4228998, 3932862, 3164983, 3101093, 2807387, 2520609, 2282372, 2162001, 2130477, 1811036, 1706559, 1522697, 1410061, 1392945, 1380023, 1335999, 1128202, 893518, 864064, 835552, 811306, 808262, 789008, 735626, 695975, 600428, 593453, 566412, 552087, 494106, 486833, 479391, 475207, 442202, 440671, 415705, 401826, 380572, 345759, 325993, 316269, 297514, 295114, 274869, 273137, 266805, 254736, 247099, 243778, 238613, 237260, 223957, 219325, 215791, 209462, 207832, 203055, 202926, 200382, 196475, 196421, 187716, 179563, 175198, 174243, 171985, 168335, 167888, 159252, 144831, 143321, 142059, 140688, 138542, 127800, 114543, 114209, 109643, 108350, 93263, 90997, 86737, 86606, 86343, 82897, 80803, 80247, 77489, 76484, 65527, 63110, 62882, 61539, 60052, 57607, 56822, 55894, 40490, 40337, 37650, 36794, 36321, 36039, 35477, 32912, 32528, 29061, 28766, 27465, 26684, 26501, 24847, 21114, 21034, 20155, 19779, 18495, 18413, 17365, 17191, 16912, 16693, 16117, 16015, 15826, 13801, 12594, 12345, 12187, 11121, 11089, 10525, 10149, 9179, 8985, 8870, 8847, 8642, 8613, 8577, 8177, 7736, 7680, 6928, 6537, 6371, 6338, 6181, 6067, 5023, 4835, 4830, 4792, 4255, 4214, 4043, 3984, 3922, 3902, 3606, 3372, 3333, 3319, 3032, 2944, 2594, 2586, 2526, 2409, 2339, 2177, 2076, 2048, 2026, 1977, 1670, 1663, 1571, 1060, 977, 952, 868, 862, 724, 660, 641, 638, 587, 509, 460, 191, 153, 151, 142, 70, 66, 54, 48, 47, 27, 20, 19, 18, 10, 3, 3], "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "showscale": true}, "type": "bar", "x": ["USA", "India", "Brazil", "Russia", "UK", "France", "Spain", "Italy", "Turkey", "Germany", "Colombia", "Argentina", "Mexico", "Poland", "Iran", "South Africa", "Ukraine", "Indonesia", "Peru", "Czechia", "Netherlands", "Canada", "Chile", "Romania", "Portugal", "Israel", "Belgium", "Iraq", "Sweden", "Philippines", "Pakistan", "Switzerland", "Bangladesh", "Serbia", "Morocco", "Austria", "Hungary", "Jordan", "Japan", "UAE", "Lebanon", "Saudi Arabia", "Panama", "Slovakia", "Malaysia", "Belarus", "Ecuador", "Nepal", "Georgia", "Bulgaria", "Bolivia", "Croatia", "Dominican Republic", "Tunisia", "Azerbaijan", "Ireland", "Kazakhstan", "Denmark", "Greece", "Costa Rica", "Kuwait", "Lithuania", "Palestine", "Moldova", "Slovenia", "Egypt", "Guatemala", "Armenia", "Honduras", "Paraguay", "Ethiopia", "Qatar", "Nigeria", "Oman", "Venezuela", "Myanmar", "Libya", "Bosnia and Herzegovina", "Bahrain", "Algeria", "Albania", "Kenya", "North Macedonia", "S. Korea", "Latvia", "Ghana", "Kyrgyzstan", "Sri Lanka", "Zambia", "Montenegro", "Uzbekistan", "Estonia", "Norway", "Uruguay", "Finland", "Mozambique", "El Salvador", "Singapore", "Cuba", "Luxembourg", "Afghanistan", "Uganda", "Namibia", "Cyprus", "Cameroon", "Zimbabwe", "Senegal", "Ivory Coast", "Botswana", "Malawi", "Australia", "Sudan", "Jamaica", "DRC", "Thailand", "Malta", "Angola", "Maldives", "Madagascar", "Rwanda", "French Polynesia", "Mayotte", "Mauritania", "Eswatini", "Guinea", "French Guiana", "Syria", "Gabon", "Cabo Verde", "R\u00e9union", "Haiti", "Belize", "Burkina Faso", "Hong Kong", "Andorra", "Lesotho", "Guadeloupe", "Congo", "Suriname", "South Sudan", "Guyana", "Bahamas", "Mali", "Somalia", "Aruba", ...
